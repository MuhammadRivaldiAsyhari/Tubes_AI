# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhammadRivaldiAsyhari/Tubes_AI/blob/main/Tubes_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Model dataset

# %% [markdown]
# 001. Mount Google

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# Kita buat beberapa folder yang akan kita gunakan untuk menampung hasil dari pemrosesan nanti
# importing os module 
import os

# Parent Directory path
parent_dir = "/content/gdrive/MyDrive/Colab Notebooks/Transfer Learning (Image Classification)"

# 01 - Membuat folder dengan nama 'Dataset Original' ---> Untuk menampung dataset kita
directory_dataset_original = "Dataset Original"

# Path
path = os.path.join(parent_dir, directory_dataset_original)

# Create the directory

try:
    os.mkdir(path)
    print("Directory " + directory_dataset_original + " created")
except OSError as error:
    print(error)
# Out:
# [Errno 17] File exists: '/content/gdrive/MyDrive/Colab Notebooks/Transfer Learning (Image Classification)/Dataset Original'

# %%
# 02 - Membuat folder dengan nama 'Analyze Dataset' ---> Untuk menampung hasil proses splitting dan cek dataset
directory_analyze_dataset = "Analyze Dataset"

# Path
path = os.path.join(parent_dir, directory_analyze_dataset)

# Create the directory
try:
    os.mkdir(path)
    print("Directory " + directory_analyze_dataset + " created")
except OSError as error:
    print(error)
# Out:
# [Errno 17] File exists: '/content/gdrive/MyDrive/Colab Notebooks/Transfer Learning (Image Classification)/Analyze Dataset'

# %%
# 03 - Membuat folder dengan nama 'Model Dataset' ---> Pada tahap ini kita telah memg-compile model kita dan menyimpannya di folder ini
directory_model_dataset = "Model Dataset"

# Path
path = os.path.join(parent_dir, directory_model_dataset)

# Create the directory
try:
    os.mkdir(path)
    print("Directory " + directory_model_dataset + " created")
except OSError as error:
    print(error)
# Out:
# Directory Model Dataset created

# %%
# 04 - Membuat folder dengan nama 'Test Algorithm' ---> Voila!, test your dataset and save them here 
directory_test_algorithm = "Test Algorithm"

# Path
path = os.path.join(parent_dir, directory_test_algorithm)

# Create the directory
try:
    os.mkdir(path)
    print("Directory " + directory_test_algorithm + " created")
except OSError as error:
    print(error)
# Out:
# [Errno 17] File exists: '/content/gdrive/MyDrive/Colab Notebooks/Transfer Learning (Image Classification)/Test Algorithm'

# %%
# 05 - Membuat folder dengan nama 'Kaggle' ---> untuk menyimpan kaggle.json (token) yang didapat dari akun kaggle
directory_test_algorithm = "Kaggle"

parent_dir_kaggle = "/content/gdrive/MyDrive/Colab Notebooks"

# Path
path = os.path.join(parent_dir_kaggle, directory_test_algorithm)

# Create the directory
try:
    os.mkdir(path)
    print("Directory " + directory_test_algorithm + " created")
except OSError as error:
    print(error)
# Out:
# [Errno 17] File exists: '/content/gdrive/MyDrive/Colab Notebooks/Kaggle'

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = "/content/gdrive/MyDrive/Colab Notebooks/Kaggle"

# %%
# %cd /content/gdrive/MyDrive/Colab Notebooks/Kaggle
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/Kaggle

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-f7482308-a21f-410d-adb2-fb2bcf7101d8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f7482308-a21f-410d-adb2-fb2bcf7101d8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle (2).json
# User uploaded file "kaggle.json" with length 66 bytes

# %%
# %cd "/content/gdrive/MyDrive/Colab Notebooks/Transfer Learning (Image Classification)/Dataset Original"
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/Transfer Learning (Image Classification)/Dataset Original

# %%
# !kaggle datasets download -d rizkikecek/dataset-herbal-leaves
# Out:
# ...
# 100% 1.14G/1.14G [00:13<00:00, 99.2MB/s]
# 100% 1.14G/1.14G [00:13<00:00, 91.4MB/s]

# %% [markdown]
# preprocessing

# %%
# Mengarahkan terminal environment ke folder dataset berada
# %cd "/content/gdrive/MyDrive/Colab Notebooks/Transfer Learning (Image Classification)/Dataset Original"
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/Transfer Learning (Image Classification)/Dataset Original

# %%
# Mengecek isi dari folder directory saat ini
# !ls
# Out:
# dataset-herbal-leaves.zip

# %% [markdown]
# Analyze dataset

# %%
# Unzip file dan hapus zip file
# !unzip \*.zip
# Out:
# Archive:  dataset-herbal-leaves.zip
#   inflating: train/Belimbing Wuluh/Belimbing Wuluh10.jpg
#   inflating: train/Belimbing Wuluh/Belimbing Wuluh100.jpg
#   inflating: train/Belimbing Wuluh/Belimbing Wuluh102.jpg
#   inflating: train/Belimbing Wuluh/Belimbing Wuluh104.jpg
#   inflating: train/Belimbing Wuluh/Belimbing Wuluh105.jpg
#   inflating: train/Belimbing Wuluh/Belimbing Wuluh106.jpg
#   inflating: train/Belimbing Wuluh/Belimbing Wuluh107.jpg
#   inflating: train/Belimbing Wuluh/Belimbing Wuluh108.jpg
#   inflating: train/Belimbing Wuluh/Belimbing Wuluh109.jpg
#   inflating: train/Belimbing Wuluh/Belimbing Wuluh11.jpg
#   inflating: train/Belimbing Wuluh/Belimbing Wuluh110.jpg
#   inflating: train/Belimbing Wuluh/Belimbing Wuluh111.jpg
#   inflating: train/Belimbing Wuluh/Belimbing Wuluh112.jpg
#   inflating: train/Belimbing Wuluh/Belimbing Wuluh113.jpg
#   inflating: train/Belimbing Wuluh/Belimbing Wuluh115.jpg
#   inflating: train/Belimbing Wuluh/Belimbing Wuluh116.jpg
# ...

# %%
# Memindah folder train dan val ke Analyze Dataset
# Dataset train
# !mv "/content/gdrive/MyDrive/Colab Notebooks/Transfer Learning (Image Classification)/Dataset Original/train" "/content/gdrive/MyDrive/Colab Notebooks/Transfer Learning (Image Classification)/Analyze Dataset" 

# Dataset val
# !mv "/content/gdrive/MyDrive/Colab Notebooks/Transfer Learning (Image Classification)/Dataset Original/val" "/content/gdrive/MyDrive/Colab Notebooks/Transfer Learning (Image Classification)/Analyze Dataset"

# %%
import os

train_dir = "/content/gdrive/MyDrive/Colab Notebooks/Transfer Learning (Image Classification)/Analyze Dataset/train"
val_dir = "/content/gdrive/MyDrive/Colab Notebooks/Transfer Learning (Image Classification)/Analyze Dataset/val"

# Path Train Per Class
belimbing_wuluh_train_path = train_dir + "/Belimbing Wuluh"
jambu_biji_train_path = train_dir + "/Jambu biji"
jeruk_train_path = train_dir + "/Jeruk"
kemangi_train_path = train_dir + "/Kemangi"
lidah_buaya_train_path = train_dir + "/Lidah buaya"
nangka_train_path = train_dir + "/Nangka"
pandan_train_path = train_dir + "/Pandan"
pepaya_train_path = train_dir + "/Pepaya"
seledri_train_path = train_dir + "/Seledri"
sirih_train_path = train_dir + "/Sirih"

# Path Val Per Class
belimbing_wuluh_val_path = val_dir + "/Belimbing Wuluh"
jambu_biji_val_path = val_dir + "/Jambu biji"
jeruk_val_path = val_dir + "/Jeruk"
kemangi_val_path = val_dir + "/Kemangi"
lidah_buaya_val_path = val_dir + "/Lidah buaya"
nangka_val_path = val_dir + "/Nangka"
pandan_val_path = val_dir + "/Pandan"
pepaya_val_path = val_dir + "/Pepaya"
seledri_val_path = val_dir + "/Seledri"
sirih_val_path = val_dir + "/Sirih"

# Len Train Per Class
belimbing_wuluh_len_train = len(os.listdir(belimbing_wuluh_train_path))
jambu_biji_len_train = len(os.listdir(jambu_biji_train_path))
jeruk_len_train = len(os.listdir(jeruk_train_path))
kemangi_len_train = len(os.listdir(kemangi_train_path))
lidah_buaya_len_train = len(os.listdir(lidah_buaya_train_path))
nangka_len_train = len(os.listdir(nangka_train_path))
pandan_len_train = len(os.listdir(pandan_train_path))
pepaya_len_train = len(os.listdir(pepaya_train_path))
seledri_len_train = len(os.listdir(seledri_train_path))
sirih_len_train = len(os.listdir(sirih_train_path))

# Len Val Per Class
belimbing_wuluh_len_val = len(os.listdir(belimbing_wuluh_val_path))
jambu_biji_len_val = len(os.listdir(jambu_biji_val_path))
jeruk_len_val = len(os.listdir(jeruk_val_path))
kemangi_len_val = len(os.listdir(kemangi_val_path))
lidah_buaya_len_val = len(os.listdir(lidah_buaya_val_path))
nangka_len_val = len(os.listdir(nangka_val_path))
pandan_len_val = len(os.listdir(pandan_val_path))
pepaya_len_val = len(os.listdir(pepaya_val_path))
seledri_len_val = len(os.listdir(seledri_val_path))
sirih_len_val = len(os.listdir(sirih_val_path))

print("Jumlah dataset training                : ", belimbing_wuluh_len_train + jambu_biji_len_train + jeruk_len_train + kemangi_len_train + lidah_buaya_len_train + nangka_len_train + pandan_len_train + pepaya_len_train + seledri_len_train + sirih_len_train)
print("Jumlah dataset validasi                : ", belimbing_wuluh_len_val + jambu_biji_len_val + jeruk_len_val + kemangi_len_val + lidah_buaya_len_val + nangka_len_val + pandan_len_val + pepaya_len_val + seledri_len_val + sirih_len_val)
print()
print("Jumlah train kelas belimbing wuluh     : ", belimbing_wuluh_len_train)
print("Jumlah train kelas jambu biji          : ", jambu_biji_len_train)
print("Jumlah train kelas jeruk               : ", jeruk_len_train)
print("Jumlah train kelas kemangi             : ", kemangi_len_train)
print("Jumlah train kelas lidah buaya         : ", lidah_buaya_len_train)
print("Jumlah train kelas nangka              : ", nangka_len_train)
print("Jumlah train kelas pandan              : ", pandan_len_train)
print("Jumlah train kelas pepaya              : ", pepaya_len_train)
print("Jumlah train kelas seledri             : ", seledri_len_train)
print("Jumlah train kelas sirih               : ", sirih_len_train)
print()
print("Jumlah validasi kelas belimbing wuluh  : ", belimbing_wuluh_len_val)
print("Jumlah validasi kelas jambu biji       : ", jambu_biji_len_val)
print("Jumlah validasi kelas jeruk            : ", jeruk_len_val)
print("Jumlah validasi kelas kemangi          : ", kemangi_len_val)
print("Jumlah validasi kelas lidah buaya      : ", lidah_buaya_len_val)
print("Jumlah validasi kelas nangka           : ", nangka_len_val)
print("Jumlah validasi kelas pandan           : ", pandan_len_val)
print("Jumlah validasi kelas pepaya           : ", pepaya_len_val)
print("Jumlah validasi kelas seledri          : ", seledri_len_val)
print("Jumlah validasi kelas sirih            : ", sirih_len_val)
# Out:
# Jumlah dataset training                :  2590
# Jumlah dataset validasi                :  870
#
# Jumlah train kelas belimbing wuluh     :  259
# Jumlah train kelas jambu biji          :  259
# Jumlah train kelas jeruk               :  259
# Jumlah train kelas kemangi             :  259
# Jumlah train kelas lidah buaya         :  259
# Jumlah train kelas nangka              :  259
# Jumlah train kelas pandan              :  259
# Jumlah train kelas pepaya              :  259
# Jumlah train kelas seledri             :  259
# Jumlah train kelas sirih               :  259
#
# Jumlah validasi kelas belimbing wuluh  :  87
# Jumlah validasi kelas jambu biji       :  87
# Jumlah validasi kelas jeruk            :  87
# Jumlah validasi kelas kemangi          :  87
# Jumlah validasi kelas lidah buaya      :  87
# Jumlah validasi kelas nangka           :  87
# Jumlah validasi kelas pandan           :  87
# Jumlah validasi kelas pepaya           :  87
# ...

# %%
train_belimbing_wuluh_fnames = os.listdir(belimbing_wuluh_train_path)
train_jambu_biji_fnames = os.listdir(jambu_biji_train_path)
train_jeruk_fnames = os.listdir(jeruk_train_path)
train_kemangi_fnames = os.listdir(kemangi_train_path)
train_lidah_buaya_fnames = os.listdir(lidah_buaya_train_path)
train_nangka_fnames = os.listdir(nangka_train_path)
train_pandan_fnames = os.listdir(pandan_train_path)
train_pepaya_fnames = os.listdir(pepaya_train_path)
train_seledri_fnames = os.listdir(seledri_train_path)
train_sirih_fnames = os.listdir(sirih_train_path)

print("belimbing wuluh    : ", train_belimbing_wuluh_fnames[:10])
print("jambu biji         : ", train_jambu_biji_fnames[:10])
print("jeruk              : ", train_jeruk_fnames[:10])
print("kemangi            : ", train_kemangi_fnames[:10])
print("lidah buaya        : ", train_lidah_buaya_fnames[:10])
print("nangka             : ", train_nangka_fnames[:10])
print("pandan             : ", train_pandan_fnames[:10])
print("pepaya             : ", train_pepaya_fnames[:10])
print("seledri            : ", train_seledri_fnames[:10])
print("sirih              : ", train_sirih_fnames[:10])
# Out:
# belimbing wuluh    :  ['Belimbing Wuluh10.jpg', 'Belimbing Wuluh100.jpg', 'Belimbing Wuluh102.jpg', 'Belimbing Wuluh104.jpg', 'Belimbing Wuluh105.jpg', 'Belimbing Wuluh106.jpg', 'Belimbing Wuluh107.jpg', 'Belimbing Wuluh108.jpg', 'Belimbing Wuluh109.jpg', 'Belimbing Wuluh11.jpg']
# jambu biji         :  ['Jambu biji10.jpg', 'Jambu biji100.jpg', 'Jambu biji102.jpg', 'Jambu biji104.jpg', 'Jambu biji105.jpg', 'Jambu biji106.jpg', 'Jambu biji107.jpg', 'Jambu biji108.jpg', 'Jambu biji109.jpg', 'Jambu biji11.jpg']
# jeruk              :  ['Jeruk10.jpg', 'Jeruk100.jpg', 'Jeruk102.jpg', 'Jeruk104.jpg', 'Jeruk105.jpg', 'Jeruk106.jpg', 'Jeruk107.jpg', 'Jeruk108.jpg', 'Jeruk109.jpg', 'Jeruk11.jpg']
# kemangi            :  ['Kemangi10.jpg', 'Kemangi100.jpg', 'Kemangi102.jpg', 'Kemangi104.jpg', 'Kemangi105.jpg', 'Kemangi106.jpg', 'Kemangi107.jpg', 'Kemangi108.jpg', 'Kemangi109.jpg', 'Kemangi11.jpg']
# ...

# %%
# import terlebih dahulu library yang diperlukan
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# Parameter dari visualisasi dimana terdiri dari 4 kolom
nrows = 20
ncols = 4

# Inisialisasi nilai awal untuk melakukan iterasi
pic_index = 0

# %%
# Mengatur matplotlib fig, dan ukuran visualisasi ke 4x4 pics

fig = plt.gcf()
fig.set_size_inches(ncols*4, nrows*4)

pic_index += 20

next_belimbing_wuluh_pix = [os.path.join(belimbing_wuluh_train_path, fname)
                   for fname in train_belimbing_wuluh_fnames[pic_index-8:pic_index]
                  ]

next_jambu_biji_pix = [os.path.join(jambu_biji_train_path, fname)
                   for fname in train_jambu_biji_fnames[pic_index-8:pic_index]
                  ]

next_jeruk_pix = [os.path.join(jeruk_train_path, fname)
                   for fname in train_jeruk_fnames[pic_index-8:pic_index]
                  ]

next_kemangi_pix = [os.path.join(kemangi_train_path, fname)
                   for fname in train_kemangi_fnames[pic_index-8:pic_index]
                  ]

next_lidah_buaya_pix = [os.path.join(lidah_buaya_train_path, fname)
                   for fname in train_lidah_buaya_fnames[pic_index-8:pic_index]
                  ]

next_nangka_pix = [os.path.join(nangka_train_path, fname)
                   for fname in train_nangka_fnames[pic_index-8:pic_index]
                  ]

next_pandan_pix = [os.path.join(pandan_train_path, fname)
                   for fname in train_pandan_fnames[pic_index-8:pic_index]
                  ]

next_pepaya_pix = [os.path.join(pepaya_train_path, fname)
                   for fname in train_pepaya_fnames[pic_index-8:pic_index]
                  ]

next_seledri_pix = [os.path.join(seledri_train_path, fname)
                   for fname in train_seledri_fnames[pic_index-8:pic_index]
                  ]

next_sirih_pix = [os.path.join(sirih_train_path, fname)
                   for fname in train_sirih_fnames[pic_index-8:pic_index]
                  ]

for i, img_path in enumerate(next_belimbing_wuluh_pix + next_jambu_biji_pix + next_jeruk_pix + next_kemangi_pix + next_lidah_buaya_pix + next_nangka_pix + next_pandan_pix + next_pepaya_pix + next_seledri_pix + next_sirih_pix):
  # Menyeting subplot
  sp = plt.subplot(nrows, ncols, i + 1)
  # set axis 'on' to show gridlines else hide
  sp.axis("off")

  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()
